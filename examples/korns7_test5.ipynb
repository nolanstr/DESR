# %% [markdown]
# # Generic Example Test for Differential Evolution Based Symbolic Regression (DESR) for Equation: y = sin(X) + 2 + e #

# %% [markdown]
# ## Import Relevant Packages ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys;sys.path.append("../")
from desr import Generator, Equation, TrainingData, \
                 Optimizer, LaplaceApproximation, DifferentialEvolution

# %% [markdown]
# ## Initialize Data (This can be done using either numpy/torch for data) ##

# %%
X = np.random.uniform(0, 50, 100)
X.sort()
y = 213.81 * (1 - np.exp(-0.547 * X)) 
std_dev = y.std()/2
y_noisy = y + np.random.normal(loc=0, scale=std_dev, size=X.shape)
training_data = TrainingData(x=X, y=y_noisy)

plt.plot(X, y, label="Noiseless Data", color="k")
plt.scatter(X, y_noisy, label="Noisy Data", color="b")
plt.xlabel(r"$X$")
plt.ylabel(r"$y$")
plt.legend()

# %% [markdown]
# ## Initialize Optimizer (Used for deterministic optimization), Generator and Operators ##

# %%
optimizer = Optimizer(training_data, bounds=[-300, 300])
generator = Generator(genotype_size=16, X_dim=training_data.x.shape[1])
operators = ["add", "sub", "mult", "sqrt", "pow", "log", "sin", "pow"]
generator.add_operators(operators)

# %% [markdown]
# ## Initialize Bayesian Fitness (Laplace Approximation for Marginal Likelihood) and Differential Evolution Instance

# %%
laplace_approximation = LaplaceApproximation(optimizer)
differential_evolution = DifferentialEvolution(chains=20, generator=generator,
                            bayesian_fitness=laplace_approximation)

equation = Equation(expression="C_0 - C_0 * exp(-C_1 * X_0)")
print(f"Target Fitness: {laplace_approximation(equation)}")
print(equation)
fig, ax = plt.subplots()
ax.scatter(training_data.x.detach().numpy(), training_data.y.detach().numpy(), label="Noisy Data", color="k")
ax.plot(training_data.x.detach().numpy().squeeze(), equation.evaluate_equation(training_data.x).detach().numpy().squeeze(), label="True Model", color="b")
ax.set_xlabel(r"$X$")
ax.set_ylabel(r"$y$")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# TokenError                                Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/sympy/core/sympify.py:495, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     494     a = a.replace('\n', '')
# --> 495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
#
# File /opt/homebrew/lib/python3.11/site-packages/sympy/parsing/sympy_parser.py:1072, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1070     _transformations = transformations
# -> 1072 code = stringify_expr(s, local_dict, global_dict, _transformations)
#    1074 if not evaluate:
#
# File /opt/homebrew/lib/python3.11/site-packages/sympy/parsing/sympy_parser.py:891, in stringify_expr(s, local_dict, global_dict, transformations)
#     890 input_code = StringIO(s.strip())
# --> 891 for toknum, tokval, _, _, _ in generate_tokens(input_code.readline):
#     892     tokens.append((toknum, tokval))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tokenize.py:525, in _tokenize(readline, encoding)
#     524 if not line:
# --> 525     raise TokenError("EOF in multi-line statement", (lnum, 0))
#     526 continued = 0
#
# TokenError: ('EOF in multi-line statement', (2, 0))
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# /Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> laplace_approximation = LaplaceApproximation(optimizer)
#       <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> differential_evolution = DifferentialEvolution(chains=20, generator=generator,
#       <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>                             bayesian_fitness=laplace_approximation)
# ----> <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> equation = Equation(expression="C_0 - C_0 * exp(-C_1 * X_0))")
#       <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> print(f"Target Fitness: {laplace_approximation(equation)}")
#       <a href='vscode-notebook-cell:/Users/nolanstrauss/codes/DESR/examples/korns7_test5.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> print(equation)
#
# File ~/codes/DESR/examples/../desr/GenePy/genepy/equation/equation.py:27, in Equation.__init__(self, genotype, expression)
#      18 """
#      19 Parameters
#      20 ----------
#    (...)
#      24
#      25 """
#      26 super().__init__()
# ---> 27 self._set_genetic_information(genotype, expression)
#
# File ~/codes/DESR/examples/../desr/GenePy/genepy/equation/equation.py:50, in Equation._set_genetic_information(self, genotype, expression)
#      48     self._init_from_genotype(genotype)
#      49 elif (genotype is None) and (expression is not None):
# ---> 50     self._init_from_expression(expression)
#      51 else:
#      52     warnings.warn(
#      53         "Specrified both genotype and expression, initializing from expression"
#      54     )
#
# File ~/codes/DESR/examples/../desr/GenePy/genepy/equation/equation.py:79, in Equation._init_from_expression(self, expression)
#      71 def _init_from_expression(self, expression):
#      72     """
#      73     Parameters
#      74     ----------
#    (...)
#      77
#      78     """
# ---> 79     structure_dict, ints, floats, genotype = genotype_from_expression(expression)
#      80     self._genotype = genotype
#      81     self._simplified_genotype = genotype
#
# File ~/codes/DESR/examples/../desr/GenePy/genepy/equation/genotype_from_expression.py:108, in genotype_from_expression(structure, simplify)
#      99 """
#     100 Parameters
#     101 ----------
#    (...)
#     104
#     105 """
#     107 if simplify:
# --> 108     expression, sqrt_check = make_sympy_expression(structure)
#     109     if "zoo" in str(expression) or "nan" in str(expression):
#     110         return None, {"I_0": np.nan}, {}, [[-1, 0, 0]]
#
# File ~/codes/DESR/examples/../desr/GenePy/genepy/equation/genotype_from_expression.py:314, in make_sympy_expression(string)
#     312 symbols = [sympy.Symbol(v) for v in variables]
#     313 sdict = {str(v): sympy.Symbol(v) for v in variables}
# --> 314 expr = sympify(string, evaluate=False, locals=sdict)
#     315 if "sqrt" in pre_variables:
#     316     I_terms = sum(["R_" in key for key in sdict.keys()])
#
# File /opt/homebrew/lib/python3.11/site-packages/sympy/core/sympify.py:497, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
# --> 497     raise SympifyError('could not parse %r' % a, exc)
#     499 return expr
#
# SympifyError: Sympify of expression 'could not parse 'C_0 - C_0 * exp(-C_1 * X_0))'' failed, because of exception being raised:
# TokenError: ('EOF in multi-line statement', (2, 0))

# %% [markdown]
# ## Generate Samples Using Differential Evolution ##

# %%
differential_evolution.sample(iterations=100, return_states=False)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/Users/nolanstrauss/codes/DESR/examples/../desr/differential_evolution.py:62: RuntimeWarning: overflow encountered in exp
#   ratio = np.exp(-proposed_state.fitness+current_state.fitness)
#   2%|▏         | 2/100 [00:01<01:32,  1.06it/s]/Users/nolanstrauss/codes/DESR/examples/../desr/differential_evolution.py:62: RuntimeWarning: invalid value encountered in scalar add
#   ratio = np.exp(-proposed_state.fitness+current_state.fitness)
# 100%|██████████| 100/100 [00:29<00:00,  3.35it/s]

# %% [markdown]
# ## Print All Unique Accepted States and Fitness (From high to low, note: fitness=inf may occur due to nan comparisons in initial stages) ##

# %%
N = 5 #This restricts the print to the N best fit equations found
for i, state in enumerate(differential_evolution.unique_accepted_states[-N:]):
    print(f"Model_{i} Expression: {str(state)}")
    print(f"Model_{i} Fitness: {str(state.fitness)}\n")
# Out:
# Model_0 Expression: (X_0)^(I_0)
# Model_0 Fitness: 36.079833490859116
#
# Model_1 Expression: (((X_0)^(I_1))^(I_0))^(I_0)
# Model_1 Fitness: 36.079833490859116
#
# Model_2 Expression: ((X_0 + ((I_2 * I_2) * (C_0)^(I_1))))^(I_0)
# Model_2 Fitness: 36.079833490859116
#
# Model_3 Expression: ((X_0 + log((C_0)^(I_0))))^(I_0)
# Model_3 Fitness: 36.03942303975241
#
# Model_4 Expression: ((X_0 + (I_2 * (C_0)^(I_1))))^(I_0)
# Model_4 Fitness: 36.0394230275431

# %% [markdown]
# ## Print Unique Final Accepted States and Fitness (From high to low) ##

# %%
for i, state in enumerate(differential_evolution.unique_states):
    print(f"Model_{i} Expression: {str(state)}")
    print(f"Model_{i} Fitness: {str(state.fitness)}\n")
# Out:
# Model_0 Expression: (X_0)^(0.5)
# Model_0 Fitness: 36.079833490859116

# %% [markdown]
# ## Plot N Unique Accepted States ##

# %%
fig, axs = plt.subplots()
axs.scatter(training_data.x.detach().numpy(), training_data.y.detach().numpy(), label="Noisy Data", color="k")

for i, state in enumerate(differential_evolution.unique_accepted_states[-N:]):
    axs.plot(training_data.x.detach().numpy().squeeze(), state.evaluate_equation(training_data.x).detach().numpy().squeeze(), label=f"Model_{i}")
axs.set_xlabel(r"$X$")
axs.set_ylabel(r"$y$")
if N < 5: #Ignore if legend size will be too large.
    axs.legend()
